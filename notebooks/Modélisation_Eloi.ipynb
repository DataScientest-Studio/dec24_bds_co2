# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pandas==1.3.6 (from versions: 0.1, 0.2, 0.3.0, 0.4.0, 0.4.1, 0.4.2, 0.4.3, 0.5.0, 0.6.0, 0.6.1, 0.7.0, 0.7.1, 0.7.2, 0.7.3, 0.8.0, 0.8.1, 0.9.0, 0.9.1, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.19.2, 0.20.0, 0.20.1, 0.20.2, 0.20.3, 0.21.0, 0.21.1, 0.22.0, 0.23.0, 0.23.1, 0.23.2, 0.23.3, 0.23.4, 0.24.0, 0.24.1, 0.24.2, 0.25.0, 0.25.1, 0.25.2, 0.25.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.1.4, 1.1.5, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.2.4, 1.2.5, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.3.4, 1.3.5, 1.4.0rc0, 1.4.0, 1.4.1, 1.4.2, 1.4.3, 1.4.4, 1.5.0rc0, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 2.0.0rc0, 2.0.0rc1, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc0, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.2.0rc0, 2.2.0, 2.2.1, 2.2.2, 2.2.3)
# ERROR: No matching distribution found for pandas==1.3.6

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import  matplotlib.pyplot as plt

from sklearn import model_selection  
from sklearn import ensemble  
from sklearn import svm  
from sklearn import neighbors  
from sklearn.model_selection import train_test_split  
from sklearn import preprocessing  
from sklearn.ensemble import VotingClassifier  

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# # Données propres

# %%
df = pd.read_csv('Donnees_propres.csv')

# %%
df.head()
# Out:
#       lib_mrq lib_mod_doss lib_mod                 dscom hybride  \
# 0  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)     non
# 1  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)     non
# 2  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)     non
# 3  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)     non
# 4  ALFA-ROMEO          159     159  159 2.0 JTDm (170ch)     non
#
#    puiss_admin_98  puiss_max  conso_urb  conso_exurb  conso_mixte  ...   ptcl  \
# 0              12      147.0       11.3          5.8          7.8  ...  0.002
# 1              12      147.0       11.5          6.0          8.0  ...  0.002
# 2               7      100.0        6.6          4.2          5.1  ...  0.001
# 3               7      100.0        6.6          4.2          5.1  ...  0.001
# 4               9      125.0        6.9          4.3          5.3  ...  0.001
#
#    masse_ordma_min  masse_ordma_max                champ_v9  Carrosserie  \
# 0             1505             1505  715/2007*692/2008EURO5      BERLINE
# 1             1555             1555  715/2007*692/2008EURO5      BERLINE
# 2             1565             1565  715/2007*692/2008EURO5      BERLINE
# 3             1565             1565  715/2007*692/2008EURO5      BERLINE
# 4             1565             1565  715/2007*692/2008EURO5      BERLINE
#
#        gamme carburant typ_boite nb_rapp etiquette
# 0  MOY-SUPER   Essence  Manuelle       6         E
# 1  MOY-SUPER   Essence  Manuelle       6         E
# 2  MOY-SUPER    Gazoil  Manuelle       6         C
# 3  MOY-SUPER    Gazoil  Manuelle       6         C
# 4  MOY-SUPER    Gazoil  Manuelle       6         C
#
# [5 rows x 23 columns]

# %%
df = pd.read_csv('Donnees_propres.csv')
df.head()
# Out:
#       lib_mrq lib_mod_doss lib_mod                 dscom hybride  \
# 0  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)     non
# 1  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)     non
# 2  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)     non
# 3  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)     non
# 4  ALFA-ROMEO          159     159  159 2.0 JTDm (170ch)     non
#
#    puiss_admin_98  puiss_max  conso_urb  conso_exurb  conso_mixte  ...   ptcl  \
# 0              12      147.0       11.3          5.8          7.8  ...  0.002
# 1              12      147.0       11.5          6.0          8.0  ...  0.002
# 2               7      100.0        6.6          4.2          5.1  ...  0.001
# 3               7      100.0        6.6          4.2          5.1  ...  0.001
# 4               9      125.0        6.9          4.3          5.3  ...  0.001
#
#    masse_ordma_min  masse_ordma_max                champ_v9  Carrosserie  \
# 0             1505             1505  715/2007*692/2008EURO5      BERLINE
# 1             1555             1555  715/2007*692/2008EURO5      BERLINE
# 2             1565             1565  715/2007*692/2008EURO5      BERLINE
# 3             1565             1565  715/2007*692/2008EURO5      BERLINE
# 4             1565             1565  715/2007*692/2008EURO5      BERLINE
#
#        gamme carburant typ_boite nb_rapp etiquette
# 0  MOY-SUPER   Essence  Manuelle       6         E
# 1  MOY-SUPER   Essence  Manuelle       6         E
# 2  MOY-SUPER    Gazoil  Manuelle       6         C
# 3  MOY-SUPER    Gazoil  Manuelle       6         C
# 4  MOY-SUPER    Gazoil  Manuelle       6         C
#
# [5 rows x 23 columns]

# %%
df['hybride'] = df ['hybride'].replace({'oui' : 1, 'non' : 0})

etiquette_dico = {'A' : 0, 'B' : 1, 'C' : 2, 'D' : 3, 'E' : 4, 'F' : 5, 'G' : 6}
df['etiquette'] = df['etiquette'].replace(etiquette_dico)
# Out:
# C:\Users\juliette\AppData\Local\Temp\ipykernel_54344\4184738555.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['hybride'] = df ['hybride'].replace({'oui' : 1, 'non' : 0})
# C:\Users\juliette\AppData\Local\Temp\ipykernel_54344\4184738555.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['etiquette'] = df['etiquette'].replace(etiquette_dico)

# %%
df.head()
# Out:
#       lib_mrq lib_mod_doss lib_mod                 dscom  hybride  \
# 0  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)        0
# 1  ALFA-ROMEO          159     159  159 1750 Tbi (200ch)        0
# 2  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)        0
# 3  ALFA-ROMEO          159     159  159 2.0 JTDm (136ch)        0
# 4  ALFA-ROMEO          159     159  159 2.0 JTDm (170ch)        0
#
#    puiss_admin_98  puiss_max  conso_urb  conso_exurb  conso_mixte  ...   ptcl  \
# 0              12      147.0       11.3          5.8          7.8  ...  0.002
# 1              12      147.0       11.5          6.0          8.0  ...  0.002
# 2               7      100.0        6.6          4.2          5.1  ...  0.001
# 3               7      100.0        6.6          4.2          5.1  ...  0.001
# 4               9      125.0        6.9          4.3          5.3  ...  0.001
#
#    masse_ordma_min  masse_ordma_max                champ_v9  Carrosserie  \
# 0             1505             1505  715/2007*692/2008EURO5      BERLINE
# 1             1555             1555  715/2007*692/2008EURO5      BERLINE
# 2             1565             1565  715/2007*692/2008EURO5      BERLINE
# 3             1565             1565  715/2007*692/2008EURO5      BERLINE
# 4             1565             1565  715/2007*692/2008EURO5      BERLINE
#
#        gamme carburant typ_boite nb_rapp etiquette
# 0  MOY-SUPER   Essence  Manuelle       6         4
# 1  MOY-SUPER   Essence  Manuelle       6         4
# 2  MOY-SUPER    Gazoil  Manuelle       6         2
# 3  MOY-SUPER    Gazoil  Manuelle       6         2
# 4  MOY-SUPER    Gazoil  Manuelle       6         2
#
# [5 rows x 23 columns]

# %%
df.nunique()
# Out:
# lib_mrq              40
# lib_mod_doss        377
# lib_mod             352
# dscom              3095
# hybride               2
# puiss_admin_98       48
# puiss_max           153
# conso_urb           155
# conso_exurb          77
# conso_mixte         104
# co2                 203
# co_typ_1            478
# nox                 220
# ptcl                  8
# masse_ordma_min     731
# masse_ordma_max     772
# champ_v9             34
# Carrosserie          11
# gamme                 6
# carburant             4
# typ_boite             3
# nb_rapp               6
# etiquette             7
# dtype: int64

# %%
df.drop(['lib_mrq', 'lib_mod_doss', 'lib_mod', 'dscom', 'champ_v9', ], axis=1, inplace = True)

# %%
df_encoded = pd.get_dummies(df, dtype='int' )

# %%
df_encoded
# Out:
#        hybride  puiss_admin_98  puiss_max  conso_urb  conso_exurb  \
# 0            0              12      147.0       11.3          5.8
# 1            0              12      147.0       11.5          6.0
# 2            0               7      100.0        6.6          4.2
# 3            0               7      100.0        6.6          4.2
# 4            0               9      125.0        6.9          4.3
# ...        ...             ...        ...        ...          ...
# 52303        0               9      133.0        4.9          4.3
# 52304        0              10      133.0        5.6          4.5
# 52305        0              11      133.0        8.6          5.2
# 52306        0              13      158.0        8.6          5.2
# 52307        0              12      158.0        6.1          4.8
#
#        conso_mixte    co2  co_typ_1    nox   ptcl  ...  gamme_MOY-INFER  \
# 0              7.8  182.0     0.647  0.032  0.002  ...                0
# 1              8.0  186.0     0.647  0.032  0.002  ...                0
# 2              5.1  134.0     0.066  0.149  0.001  ...                0
# 3              5.1  134.0     0.066  0.149  0.001  ...                0
# 4              5.3  139.0     0.060  0.164  0.001  ...                0
# ...            ...    ...       ...    ...    ...  ...              ...
# 52303          4.5  117.0     0.215  0.068  0.000  ...                0
# 52304          4.9  129.0     0.114  0.048  0.002  ...                0
# 52305          6.4  169.0     0.344  0.116  0.000  ...                0
# 52306          6.4  169.0     0.344  0.116  0.000  ...                0
# 52307          5.3  139.0     0.285  0.106  0.000  ...                0
#
#        gamme_MOY-SUPER  gamme_SUPERIEURE  carburant_Essence  \
# 0                    1                 0                  1
# 1                    1                 0                  1
# 2                    1                 0                  0
# 3                    1                 0                  0
# 4                    1                 0                  0
# ...                ...               ...                ...
# 52303                0                 1                  0
# 52304                0                 1                  0
# 52305                0                 1                  0
# 52306                0                 1                  0
# 52307                0                 1                  0
#
#        carburant_Essence/Elec  carburant_Gasoil/Elec  carburant_Gazoil  \
# 0                           0                      0                 0
# 1                           0                      0                 0
# 2                           0                      0                 1
# 3                           0                      0                 1
# 4                           0                      0                 1
# ...                       ...                    ...               ...
# 52303                       0                      0                 1
# 52304                       0                      0                 1
# 52305                       0                      0                 1
# 52306                       0                      0                 1
# 52307                       0                      0                 1
#
#        typ_boite_Auto  typ_boite_Manuelle  typ_boite_Var_continue
# 0                   0                   1                       0
# 1                   0                   1                       0
# 2                   0                   1                       0
# 3                   0                   1                       0
# 4                   0                   1                       0
# ...               ...                 ...                     ...
# 52303               0                   1                       0
# 52304               1                   0                       0
# 52305               1                   0                       0
# 52306               1                   0                       0
# 52307               0                   1                       0
#
# [52308 rows x 38 columns]

# %% [markdown]
# ## premiers modèles

# %% [markdown]
# Avec toutes les données

# %%
X = df_encoded.drop(['etiquette', 'co2'], axis=1)
y = df_encoded['etiquette']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
scaler = preprocessing.StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# SVM

# %%
SVM = svm.SVC()
parametres = {'C':[0.1,1,10,30],
              'kernel':['linear', 'sigmoid', 'rbf']}
clf_svm = model_selection.GridSearchCV(SVM, parametres, cv=5, scoring='accuracy')

# %%
SVM = svm.SVC()
parametres = {'C':[0.1,1,10,30],
              'kernel':['linear', 'sigmoid', 'rbf']}

clf_svm = model_selection.GridSearchCV(SVM, parametres, cv=5, scoring='accuracy')
X_train_scaled = np.array(X_train_scaled)
y_train = np.array(y_train).ravel()
clf_svm.fit(X_train_scaled, y_train)
print("Meilleurs paramètres :", clf_svm.best_params_)
print("Meilleur score :", clf_svm.best_score_)
y_pred_svm_best = clf_svm.best_estimator_.predict(X_test_scaled)
print(pd.crosstab(y_test, y_pred_svm_best, rownames=['Classe réelle'], colnames=['Classe prédite']))
# Out:
# Meilleurs paramètres : {'C': 10, 'kernel': 'linear'}
# Meilleur score : 0.9979789703673358
# Classe prédite   0    1    2    3     4     5    6
# Classe réelle
# 0               68    0    0    0     0     0    0
# 1                0  373    2    0     0     0    0
# 2                0    9  678    1     0     0    0
# 3                0    0    5  458     8     0    0
# 4                0    0    0    5  4846     2    0
# 5                0    0    0    0     0  9064    1
# 6                0    0    0    0     0     0  173

# %%
print("\nRapport de classification :")
print(classification_report(y_test, y_pred_svm_best))
# Out:
# Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        68
#            1       0.98      0.99      0.99       375
#            2       0.99      0.99      0.99       688
#            3       0.99      0.97      0.98       471
#            4       1.00      1.00      1.00      4853
#            5       1.00      1.00      1.00      9065
#            6       0.99      1.00      1.00       173
#
#     accuracy                           1.00     15693
#    macro avg       0.99      0.99      0.99     15693
# weighted avg       1.00      1.00      1.00     15693

# %% [markdown]
# Randomforest

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=300, random_state=42)
model.fit(X_train_scaled, y_train)

# Prediction
y_pred = model.predict(X_test_scaled)


# Résultats
print('score données train', model.score(X_train_scaled, y_train))
print('score données test', model.score(X_test_scaled, y_test))
print(classification_report(y_test, y_pred))

cnf_matrix = confusion_matrix(y_test, y_pred, normalize='true').round(2)

plt.figure(figsize=(8, 6))
plt.title("Matrice de confusion n = 300")
sns.heatmap(cnf_matrix, cmap='Blues', annot=True, cbar=False)
plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')
plt.show()

# %% [markdown]
# Soit il y a un leak, soit certaines données sont beaucoup trop corrélé

# %% [markdown]
# ### Test svm et randomforest avec moins de variables

# %%
X2 = df_encoded.drop(['etiquette', 'co2', 'conso_mixte','puiss_max', 'conso_urb', 'conso_exurb'], axis=1)
y2 = df_encoded['etiquette']

X2_train, X2_test, y2_train, y2_test = train_test_split(X2,y2, test_size=0.3, random_state=42)

# %%
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.transform(X2_test)

# %% [markdown]
# SVM

# %%
clf_svm2 = model_selection.GridSearchCV(SVM, parametres, cv=5, scoring='accuracy')
X2_train_scaled = np.array(X2_train_scaled)
y2_train = np.array(y2_train).ravel()
clf_svm2.fit(X2_train_scaled, y2_train)
print("Meilleurs paramètres :", clf_svm2.best_params_)
print("Meilleur score :", clf_svm2.best_score_)
y_pred_svm2_best = clf_svm2.best_estimator_.predict(X2_test_scaled)
print(pd.crosstab(y2_test, y_pred_svm2_best, rownames=['Classe réelle'], colnames=['Classe prédite']))
print("\nRapport de classification :")
print(classification_report(y2_test, y_pred_svm2_best))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       2 X2_train_scaled = np.array(X2_train_scaled)
#       3 y2_train = np.array(y2_train).ravel()
# ----> 4 clf_svm2.fit(X2_train_scaled, y2_train)
#       5 print("Meilleurs paramètres :", clf_svm2.best_params_)
#       6 print("Meilleur score :", clf_svm2.best_score_)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     885 result["fit_error"] = None
#     887 fit_time = time.time() - start_time
# --> 888 test_scores = _score(
#     889     estimator, X_test, y_test, scorer, score_params_test, error_score
#     890 )
#     891 score_time = time.time() - start_time - fit_time
#     892 if return_train_score:
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\model_selection\_validation.py:949, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     947         scores = scorer(estimator, X_test, **score_params)
#     948     else:
# --> 949         scores = scorer(estimator, X_test, y_test, **score_params)
#     950 except Exception:
#     951     if isinstance(scorer, _MultimetricScorer):
#     952         # If `_MultimetricScorer` raises exception, the `error_score`
#     953         # parameter is equal to "raise".
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\metrics\_scorer.py:288, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     285 if sample_weight is not None:
#     286     _kwargs["sample_weight"] = sample_weight
# --> 288 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\metrics\_scorer.py:380, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     378 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     379 response_method = _check_response_method(estimator, self._response_method)
# --> 380 y_pred = method_caller(
#     381     estimator,
#     382     _get_response_method_name(response_method),
#     383     X,
#     384     pos_label=pos_label,
#     385 )
#     387 scoring_kwargs = {**self._kwargs, **kwargs}
#     388 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\metrics\_scorer.py:90, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      87 if cache is not None and response_method in cache:
#      88     return cache[response_method]
# ---> 90 result, _ = _get_response_values(
#      91     estimator, *args, response_method=response_method, **kwargs
#      92 )
#      94 if cache is not None:
#      95     cache[response_method] = result
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\utils\_response.py:214, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     211     elif pos_label is None and target_type == "binary":
#     212         pos_label = classes[-1]
# --> 214 y_pred = prediction_method(X)
#     216 if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     217     y_pred = _process_predict_proba(
#     218         y_pred=y_pred,
#     219         target_type=target_type,
#     220         classes=classes,
#     221         pos_label=pos_label,
#     222     )
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\svm\_base.py:822, in BaseSVC.predict(self, X)
#     820     y = np.argmax(self.decision_function(X), axis=1)
#     821 else:
# --> 822     y = super().predict(X)
#     823 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\svm\_base.py:438, in BaseLibSVM.predict(self, X)
#     436 X = self._validate_for_predict(X)
#     437 predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 438 return predict(X)
#
# File c:\Users\juliette\anaconda3\envs\tensorflow_env\lib\site-packages\sklearn\svm\_base.py:457, in BaseLibSVM._dense_predict(self, X)
#     449         raise ValueError(
#     450             "X.shape[1] = %d should be equal to %d, "
#     451             "the number of samples at training time"
#     452             % (X.shape[1], self.shape_fit_[0])
#     453         )
#     455 svm_type = LIBSVM_IMPL.index(self._impl)
# --> 457 return libsvm.predict(
#     458     X,
#     459     self.support_,
#     460     self.support_vectors_,
#     461     self._n_support,
#     462     self._dual_coef_,
#     463     self._intercept_,
#     464     self._probA,
#     465     self._probB,
#     466     svm_type=svm_type,
#     467     kernel=kernel,
#     468     degree=self.degree,
#     469     coef0=self.coef0,
#     470     gamma=self._gamma,
#     471     cache_size=self.cache_size,
#     472 )
#
# KeyboardInterrupt:

# %% [markdown]
# RandomForest

# %%
model = RandomForestClassifier(n_estimators=300, random_state=42)
model.fit(X2_train_scaled, y2_train)

# Prediction
y_pred = model.predict(X2_test_scaled)


# Résultats
print('score données train', model.score(X2_train_scaled, y2_train))
print('score données test', model.score(X2_test_scaled, y2_test))
print(classification_report(y2_test, y2_pred))

cnf_matrix = confusion_matrix(y2_test, y_pred, normalize='true').round(2)

plt.figure(figsize=(8, 6))
plt.title("Matrice de confusion n = 300")
sns.heatmap(cnf_matrix, cmap='Blues', annot=True, cbar=False)
plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')
plt.show()

# %% [markdown]
# ### Deep learning

# %%
import tensorflow as tf
#print(tf.__version__)

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.2, random_state=42, stratify=y)

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(7, activation='softmax')  # 6 classes en sortie
])
# Out:
# c:\Users\Eloi\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',  # Utilisé car y est encodé en entiers
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2725 - loss: 2.1069 - val_accuracy: 0.6054 - val_loss: 1.2533
# Epoch 2/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5385 - loss: 1.2513 - val_accuracy: 0.7179 - val_loss: 0.8592
# Epoch 3/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6145 - loss: 0.9956 - val_accuracy: 0.7837 - val_loss: 0.6667
# Epoch 4/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6501 - loss: 0.8815 - val_accuracy: 0.8060 - val_loss: 0.5845
# Epoch 5/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6833 - loss: 0.8049 - val_accuracy: 0.8305 - val_loss: 0.5195
# Epoch 6/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7310 - loss: 0.7223 - val_accuracy: 0.8540 - val_loss: 0.4822
# Epoch 7/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7192 - loss: 0.6966 - val_accuracy: 0.8606 - val_loss: 0.4442
# Epoch 8/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7416 - loss: 0.6647 - val_accuracy: 0.8618 - val_loss: 0.4242
# Epoch 9/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7507 - loss: 0.6444 - val_accuracy: 0.8740 - val_loss: 0.4141
# Epoch 10/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.6148 - val_accuracy: 0.8930 - val_loss: 0.3876
# Epoch 11/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7732 - loss: 0.5916 - val_accuracy: 0.8997 - val_loss: 0.3629
# Epoch 12/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7906 - loss: 0.5728 - val_accuracy: 0.8997 - val_loss: 0.3476
# Epoch 13/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7954 - loss: 0.5359 - val_accuracy: 0.8997 - val_loss: 0.3452
# Epoch 14/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7945 - loss: 0.5388 - val_accuracy: 0.8952 - val_loss: 0.3314
# Epoch 15/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8270 - loss: 0.5019 - val_accuracy: 0.9052 - val_loss: 0.3234
# Epoch 16/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8059 - loss: 0.5170 - val_accuracy: 0.9008 - val_loss: 0.3050
# Epoch 17/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.4867 - val_accuracy: 0.9108 - val_loss: 0.2994
# Epoch 18/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8166 - loss: 0.5075 - val_accuracy: 0.9052 - val_loss: 0.2865
# Epoch 19/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.4562 - val_accuracy: 0.9130 - val_loss: 0.2828
# Epoch 20/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8433 - loss: 0.4413 - val_accuracy: 0.9153 - val_loss: 0.2769
# Epoch 21/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8414 - loss: 0.4735 - val_accuracy: 0.9153 - val_loss: 0.2738
# Epoch 22/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8361 - loss: 0.4399 - val_accuracy: 0.9253 - val_loss: 0.2657
# Epoch 23/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.4301 - val_accuracy: 0.9231 - val_loss: 0.2594
# Epoch 24/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8524 - loss: 0.4186 - val_accuracy: 0.9153 - val_loss: 0.2565
# Epoch 25/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8550 - loss: 0.3991 - val_accuracy: 0.9320 - val_loss: 0.2360
# Epoch 26/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8649 - loss: 0.3947 - val_accuracy: 0.9275 - val_loss: 0.2353
# Epoch 27/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8293 - loss: 0.4563 - val_accuracy: 0.9197 - val_loss: 0.2353
# Epoch 28/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8483 - loss: 0.4325 - val_accuracy: 0.9231 - val_loss: 0.2341
# Epoch 29/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8650 - loss: 0.3712 - val_accuracy: 0.9242 - val_loss: 0.2230
# Epoch 30/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8644 - loss: 0.3880 - val_accuracy: 0.9298 - val_loss: 0.2263
# Epoch 31/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8420 - loss: 0.4192 - val_accuracy: 0.9275 - val_loss: 0.2206
# Epoch 32/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8494 - loss: 0.4025 - val_accuracy: 0.9253 - val_loss: 0.2193
# Epoch 33/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8593 - loss: 0.3952 - val_accuracy: 0.9298 - val_loss: 0.2253
# Epoch 34/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8565 - loss: 0.4019 - val_accuracy: 0.9376 - val_loss: 0.2107
# Epoch 35/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8696 - loss: 0.3722 - val_accuracy: 0.9298 - val_loss: 0.2255
# Epoch 36/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8629 - loss: 0.3829 - val_accuracy: 0.9309 - val_loss: 0.2101
# Epoch 37/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8727 - loss: 0.3603 - val_accuracy: 0.9320 - val_loss: 0.2165
# Epoch 38/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8743 - loss: 0.3501 - val_accuracy: 0.9376 - val_loss: 0.1979
# Epoch 39/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8697 - loss: 0.3374 - val_accuracy: 0.9287 - val_loss: 0.2091
# Epoch 40/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8797 - loss: 0.3355 - val_accuracy: 0.9353 - val_loss: 0.1911
# Epoch 41/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8784 - loss: 0.3455 - val_accuracy: 0.9309 - val_loss: 0.1890
# Epoch 42/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.3228 - val_accuracy: 0.9353 - val_loss: 0.1924
# Epoch 43/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8963 - loss: 0.3151 - val_accuracy: 0.9320 - val_loss: 0.1811
# Epoch 44/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9036 - loss: 0.2957 - val_accuracy: 0.9365 - val_loss: 0.1959
# Epoch 45/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8717 - loss: 0.3582 - val_accuracy: 0.9342 - val_loss: 0.1827
# Epoch 46/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8833 - loss: 0.3279 - val_accuracy: 0.9431 - val_loss: 0.1829
# Epoch 47/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8845 - loss: 0.3266 - val_accuracy: 0.9387 - val_loss: 0.1864
# Epoch 48/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8735 - loss: 0.3344 - val_accuracy: 0.9420 - val_loss: 0.1698
# Epoch 49/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8890 - loss: 0.3366 - val_accuracy: 0.9409 - val_loss: 0.1772
# Epoch 50/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8780 - loss: 0.3355 - val_accuracy: 0.9476 - val_loss: 0.1728

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Perte: {loss:.4f}, Accuracy: {accuracy:.4f}')
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9515 - loss: 0.1558
# Perte: 0.1728, Accuracy: 0.9476

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test).argmax(axis=1)  # Convertit les probabilités en labels prédits

# Affichage du rapport de classification
print(classification_report(y_test, y_pred))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       119
#            1       0.95      0.96      0.95       255
#            2       0.97      0.92      0.95       226
#            3       0.88      0.95      0.92       153
#            4       0.96      0.97      0.96       137
#            5       1.00      0.40      0.57         5
#            6       1.00      1.00      1.00         2
#
#     accuracy                           0.95       897
#    macro avg       0.96      0.88      0.90       897
# weighted avg       0.95      0.95      0.95       897
